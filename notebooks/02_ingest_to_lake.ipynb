# %% [markdown]
# # 02 — Ingest to Bronze Delta Lake
#
# Reads `data/raw/hunt_logs.csv` and writes it as-is to the
# **Bronze** Delta table at `lake/bronze/hunts`.
# Bronze = raw, immutable, append-friendly; no transformations applied.

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path().resolve().parent))

from src.ingest import ingest
ingest()

# %%
# Verify by reading back from the Delta table
from deltalake import DeltaTable
import polars as pl

dt = DeltaTable("../lake/bronze/hunts")
bronze = pl.from_arrow(dt.to_pyarrow_table())
print(f"Bronze rows: {len(bronze)}")
bronze.head(3)
